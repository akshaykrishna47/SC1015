# %%
import pandas as pd 
import numpy as np 
import zipfile #used to import the data from the zip file

# %%
df_zip = zipfile.ZipFile('C:/Users/yesha/Downloads/movies_dataset.csv.zip')
df = pd.read_csv(df_zip.open('movies_dataset.csv'))
display(df)
# Out:
#        Unnamed: 0  IMDb-rating appropriate_for      director downloads  \
# 0               0          4.8               R     John Swab       304
# 1               1          6.4           TV-PG   Paul Ziller        73
# 2               2          5.2               R  Ben Wheatley     1,427
# 3               3          8.1             NaN  Venky Atluri     1,549
# 4               4          4.6             NaN  Shaji Kailas       657
# ...           ...          ...             ...           ...       ...
# 20543       20543          NaN             NaN           NaN     1,998
# 20544       20544          7.7             NaN     Bimal Roy     6,080
# 20545       20545          8.0             NaN           NaN     3,276
# 20546       20546          NaN             NaN           NaN       309
# 20547       20547          NaN             NaN           NaN     2,613
#
#            id             industry       language   posted_date release_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20548 entries, 0 to 20547
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20548 non-null  int64
#  1   IMDb-rating      19707 non-null  float64
#  2   appropriate_for  11072 non-null  object
#  3   director         18610 non-null  object
#  4   downloads        20547 non-null  object
#  5   id               20548 non-null  int64
#  6   industry         20547 non-null  object
#  7   language         20006 non-null  object
#  8   posted_date      20547 non-null  object
#  9   release_date     20547 non-null  object
#  10  run_time         18780 non-null  object
#  11  storyline        18847 non-null  object
#  12  title            20547 non-null  object
#  13  views            20547 non-null  object
#  14  writer           18356 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 2.4+ MB

# %%
print(df.dtypes)
# Out:
# Unnamed: 0           int64
# IMDb-rating        float64
# appropriate_for     object
# director            object
# downloads           object
# id                   int64
# industry            object
# language            object
# posted_date         object
# release_date        object
# run_time            object
# storyline           object
# title               object
# views               object
# writer              object
# dtype: object

# %% [markdown]
# <b> not all values are non-null, need to fill in missing values and do data cleaning <b>

# %% [markdown]
# <b> DATA CLEANING <b>

# %%
# check the number of null values 
df.isnull().sum()
# Out:
# Unnamed: 0            0
# IMDb-rating         841
# appropriate_for    9476
# director           1938
# downloads             1
# id                    0
# industry              1
# language            542
# posted_date           1
# release_date          1
# run_time           1768
# storyline          1701
# title                 1
# views                 1
# writer             2192
# dtype: int64

# %%
# for numerical values, we fill in the missing values with the mean 
df['IMDb-rating'] = df['IMDb-rating'].fillna(df['IMDb-rating'].mean())

# drop all other null values 
df = df.dropna()

df.info() 
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9911 entries, 0 to 20540
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9911 non-null   int64
#  1   IMDb-rating      9911 non-null   float64
#  2   appropriate_for  9911 non-null   object
#  3   director         9911 non-null   object
#  4   downloads        9911 non-null   object
#  5   id               9911 non-null   int64
#  6   industry         9911 non-null   object
#  7   language         9911 non-null   object
#  8   posted_date      9911 non-null   object
#  9   release_date     9911 non-null   object
#  10  run_time         9911 non-null   object
#  11  storyline        9911 non-null   object
#  12  title            9911 non-null   object
#  13  views            9911 non-null   object
#  14  writer           9911 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.2+ MB
# ...
